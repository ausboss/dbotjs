# %%
import datetime

timestamp_ms = 1713651015101
timestamp = timestamp_ms / 1000
date_time = datetime.datetime.fromtimestamp(timestamp)
print(date_time)  # Output will be a datetime object
# Out:
# 2024-04-20 17:10:15.101000
